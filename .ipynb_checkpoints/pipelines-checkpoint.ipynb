# %%
import os
import sys
from typing import Text
 
from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

from modules.components import components
from modules.utility import path

# %%
def init_local_pipeline(
    components
) -> pipeline.Pipeline:
    
    logging.info(f"Pipeline root set to: {path.PIPELINE_ROOT}")
    beam_args = [
        "--direct_running_mode=multi_processing"
        # 0 auto-detect based on on the number of CPUs available 
        # during execution time.
        "----direct_num_workers=0" 
    ]
    
    return pipeline.Pipeline(
        pipeline_name=path.PIPELINE_NAME,
        pipeline_root=path.PIPELINE_ROOT,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            path.METADATA_PATH
        ),
        eam_pipeline_args=beam_args
    )

# %%
logging.set_verbosity(logging.INFO)

# %%
components = components.init(
    training_steps=10,
    eval_steps=10,
)
# Out:
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.

# %%
pipeline = init_local_pipeline(components)
# Out:
# INFO:absl:Pipeline root set to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline

# %%
BeamDagRunner().run(pipeline=pipeline)
# Out:
# Trial 4 Complete [00h 00m 01s]
# val_accuracy: 0.551562488079071
#
# Best val_accuracy So Far: 0.551562488079071
# Total elapsed time: 00h 00m 06s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'num_layers', 'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}}], 'values': {'learning_rate': 0.01, 'num_layers': 1}}
# INFO:absl:Best Hyperparameters are written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Tuner\best_hyperparameters\15\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Tuner\tuner_results\15\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 15 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'best_hyperparameters': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Tuner\\best_hyperparameters\\15"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:best_hyperparameters:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:best_hyperparameters:0"
# , artifact_type: name: "HyperParameters"
# )], 'tuner_results': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Tuner\\tuner_results\\15"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:tuner_results:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:tuner_results:0"
# , artifact_type: name: "TunerResults"
# )]}) for execution 15
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# Results summary
# Results in C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Tuner\.system\executor_execution\15\.temp\15\imdb_sentiment_classification
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001EA0818E700>
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 1
# Score: 0.551562488079071
# Trial summary
# Hyperparameters:
# learning_rate: 0.001
# num_layers: 3
# Score: 0.5453125238418579
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 2
# Score: 0.5234375
# Trial summary
# Hyperparameters:
# learning_rate: 0.001
# num_layers: 2
# Score: 0.5062500238418579
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 10,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "trainer@C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 10,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 16
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=16, input_dict={'hyperparameters': [Artifact(artifact: id: 23
# type_id: 27
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Tuner\\best_hyperparameters\\15"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:best_hyperparameters:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Tuner:15:best_hyperparameters:0"
# create_time_since_epoch: 1668023064187
# last_update_time_since_epoch: 1668023064187
# , artifact_type: id: 27
# name: "HyperParameters"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-113927.421704:SchemaGen:4:schema:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-113927.421704:SchemaGen:4:schema:0"
# create_time_since_epoch: 1668022775759
# last_update_time_since_epoch: 1668022775759
# , artifact_type: id: 20
# name: "Schema"
# )], 'transform_graph': [Artifact(artifact: id: 19
# type_id: 25
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Transform\\transform_graph\\14"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Transform:14:transform_graph:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Transform:14:transform_graph:0"
# create_time_since_epoch: 1668023054800
# last_update_time_since_epoch: 1668023054800
# , artifact_type: id: 25
# name: "TransformGraph"
# )], 'examples': [Artifact(artifact: id: 22
# type_id: 16
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Transform\\transformed_examples\\14"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Transform:14:transformed_examples:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Transform:14:transformed_examples:0"
# create_time_since_epoch: 1668023054800
# last_update_time_since_epoch: 1668023054800
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}, output_dict=defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model_run\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model_run:0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model_run:0"
# , artifact_type: name: "ModelRun"
# )]}), exec_properties={'eval_args': '{\n  "num_steps": 10,\n  "splits": [\n    "eval"\n  ]\n}', 'custom_config': 'null', 'module_path': 'trainer@C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl', 'train_args': '{\n  "num_steps": 10,\n  "splits": [\n    "train"\n  ]\n}'}, execution_output_uri='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\.system\\executor_execution\\16\\executor_output.pb', stateful_working_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\.system\\stateful_working_dir\\20221109-114357.129105', tmp_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\.system\\executor_execution\\16\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 10,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "trainer@C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 10,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "rifkybujana-pipeline"
# , pipeline_run_id='20221109-114357.129105')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'eval_args': '{\n  "num_steps": 10,\n  "splits": [\n    "eval"\n  ]\n}', 'custom_config': 'null', 'module_path': 'trainer@C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl', 'train_args': '{\n  "num_steps": 10,\n  "splits": [\n    "train"\n  ]\n}'} 'run_fn'
# INFO:absl:Installing 'C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['C:\\Users\\rifky\\.virtualenvs\\imdb_sentiment_classification-Xv-P-UTu\\Scripts\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\rifky\\AppData\\Local\\Temp\\tmp8f7n_8h8', 'C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl']
# INFO:absl:Successfully installed 'C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+6c304347a41acb4c5f3e0eb4ec41639a41e07866804e9569fad0071a6e823960-py3-none-any.whl'.
# INFO:absl:Training model.
# INFO:absl:HyperParameters for training: {'space': [{'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'num_layers', 'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}}], 'values': {'learning_rate': 0.01, 'num_layers': 1}}
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  review_xf (InputLayer)      [(None, 1)]               0
#
#  tf.reshape_1 (TFOpLambda)   (None,)                   0
#
#  text_vectorization (TextVec  (None, 100)              0
#  torization)
#
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  global_average_pooling1d_1   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 32)                544
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 160,577
# Trainable params: 160,577
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6943 - accuracy: 0.4978
# Epoch 1: val_accuracy improved from -inf to 0.66406, saving model to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# 10/10 [==============================] - 2s 176ms/step - loss: 0.6930 - accuracy: 0.5188 - val_loss: 0.6888 - val_accuracy: 0.6641
# Epoch 2/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6743 - accuracy: 0.6942
# Epoch 2: val_accuracy did not improve from 0.66406
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6733 - accuracy: 0.6453 - val_loss: 0.6764 - val_accuracy: 0.5531
# Epoch 3/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6243 - accuracy: 0.7768
# Epoch 3: val_accuracy improved from 0.66406 to 0.68281, saving model to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# 10/10 [==============================] - 1s 143ms/step - loss: 0.6094 - accuracy: 0.8047 - val_loss: 0.6255 - val_accuracy: 0.6828
# Epoch 4/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.4898 - accuracy: 0.8304
# Epoch 4: val_accuracy improved from 0.68281 to 0.71250, saving model to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# 10/10 [==============================] - 1s 140ms/step - loss: 0.4516 - accuracy: 0.8703 - val_loss: 0.5604 - val_accuracy: 0.7125
# Epoch 5/100
#  8/10 [=======================>......] - ETA: 0s - loss: 0.3095 - accuracy: 0.9336
# Epoch 5: val_accuracy improved from 0.71250 to 0.72812, saving model to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# 10/10 [==============================] - 1s 140ms/step - loss: 0.2912 - accuracy: 0.9391 - val_loss: 0.5360 - val_accuracy: 0.7281
# Epoch 6/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.1493 - accuracy: 0.9643
# Epoch 6: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1418 - accuracy: 0.9609 - val_loss: 0.6758 - val_accuracy: 0.6750
# Epoch 7/100
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0627 - accuracy: 0.9941
# Epoch 7: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0576 - accuracy: 0.9937 - val_loss: 0.6944 - val_accuracy: 0.7156
# Epoch 8/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.0315 - accuracy: 0.9955
# Epoch 8: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0279 - accuracy: 0.9953 - val_loss: 0.7440 - val_accuracy: 0.7234
# Epoch 9/100
#  6/10 [=================>............] - ETA: 0s - loss: 0.0157 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.8795 - val_accuracy: 0.7000
# Epoch 10/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.8651 - val_accuracy: 0.7063
# Epoch 11/100
#  6/10 [=================>............] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9456 - val_accuracy: 0.6906
# Epoch 12/100
#  7/10 [====================>.........] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9673 - val_accuracy: 0.7016
# Epoch 13/100
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1000 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1000 batches). You may need to use the repeat() function when building your dataset.
# Epoch 13: val_accuracy did not improve from 0.72812
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9736 - val_accuracy: 0.7047
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:tensorflow:Assets written to: C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving\assets
# INFO:absl:Training complete. Model written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model\16\Format-Serving. ModelRun written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Trainer\model_run\16
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 16 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model_run\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model_run:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model_run:0"
# , artifact_type: name: "ModelRun"
# )]}) for execution 16
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"sentiment\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"r\",\n        \"e\",\n        \"v\",\n        \"i\",\n        \"e\",\n        \"w\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 17
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=17, input_dict={'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:1318225,xor_checksum:1668022552,sum_checksum:1668022552"
#   }
# }
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-113927.421704:CsvExampleGen:2:examples:0"
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-113927.421704:CsvExampleGen:2:examples:0"
# create_time_since_epoch: 1668022770138
# last_update_time_since_epoch: 1668022770138
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'baseline_model': [], 'model': [Artifact(artifact: id: 25
# type_id: 30
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
# create_time_since_epoch: 1668023079442
# last_update_time_since_epoch: 1668023079442
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )]}, output_dict=defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\blessing\\17"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\evaluation\\17"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:evaluation:0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:evaluation:0"
# , artifact_type: name: "ModelEvaluation"
# )]}), exec_properties={'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "sentiment"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "r",\n        "e",\n        "v",\n        "i",\n        "e",\n        "w"\n      ]\n    }\n  ]\n}', 'fairness_indicator_thresholds': 'null', 'example_splits': 'null'}, execution_output_uri='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\.system\\executor_execution\\17\\executor_output.pb', stateful_working_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\.system\\stateful_working_dir\\20221109-114357.129105', tmp_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\.system\\executor_execution\\17\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"sentiment\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"r\",\n        \"e\",\n        \"v\",\n        \"i\",\n        \"e\",\n        \"w\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001EA0EBB93D0> and <keras.engine.input_layer.InputLayer object at 0x000001EA0EBA01F0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001EA0EBB93D0> and <keras.engine.input_layer.InputLayer object at 0x000001EA0EBA01F0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001EA0FF55460> and <keras.engine.input_layer.InputLayer object at 0x000001EA0EBA0130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001EA0FF55460> and <keras.engine.input_layer.InputLayer object at 0x000001EA0EBA0130>).
# INFO:absl:Evaluation complete. Results written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Evaluator\evaluation\17.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From C:\Users\rifky\.virtualenvs\imdb_sentiment_classification-Xv-P-UTu\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From C:\Users\rifky\.virtualenvs\imdb_sentiment_classification-Xv-P-UTu\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result True written to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Evaluator\blessing\17.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 17 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\blessing\\17"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\evaluation\\17"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:evaluation:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:evaluation:0"
# , artifact_type: name: "ModelEvaluation"
# )]}) for execution 17
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"C:\\\\Users\\\\rifky\\\\Documents\\\\imdb_sentiment_classification\\\\serving_model\\\\rifkybujana-pipeline\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 18
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=18, input_dict={'model': [Artifact(artifact: id: 25
# type_id: 30
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model\\16"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Trainer:16:model:0"
# create_time_since_epoch: 1668023079442
# last_update_time_since_epoch: 1668023079442
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 27
# type_id: 33
# uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Evaluator\\blessing\\17"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Trainer\\model\\16"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 25
#   }
# }
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# state: LIVE
# name: "rifkybujana-pipeline:20221109-114357.129105:Evaluator:17:blessing:0"
# create_time_since_epoch: 1668023088544
# last_update_time_since_epoch: 1668023088544
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Pusher\\pushed_model\\18"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Pusher:18:pushed_model:0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Pusher:18:pushed_model:0"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'push_destination': '{\n  "filesystem": {\n    "base_directory": "C:\\\\Users\\\\rifky\\\\Documents\\\\imdb_sentiment_classification\\\\serving_model\\\\rifkybujana-pipeline"\n  }\n}', 'custom_config': 'null'}, execution_output_uri='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Pusher\\.system\\executor_execution\\18\\executor_output.pb', stateful_working_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Pusher\\.system\\stateful_working_dir\\20221109-114357.129105', tmp_dir='C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Pusher\\.system\\executor_execution\\18\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20221109-114357.129105"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rifkybujana-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20221109-114357.129105"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rifkybujana-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"C:\\\\Users\\\\rifky\\\\Documents\\\\imdb_sentiment_classification\\\\serving_model\\\\rifkybujana-pipeline\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "rifkybujana-pipeline"
# , pipeline_run_id='20221109-114357.129105')
# INFO:absl:Model version: 1668023088
# INFO:absl:Model written to serving path C:\Users\rifky\Documents\imdb_sentiment_classification\serving_model\rifkybujana-pipeline\1668023088.
# INFO:absl:Model pushed to C:\Users\rifky\Documents\imdb_sentiment_classification\pipelines\rifkybujana-pipeline\Pusher\pushed_model\18.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 18 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "C:\\Users\\rifky\\Documents\\imdb_sentiment_classification\\pipelines\\rifkybujana-pipeline\\Pusher\\pushed_model\\18"
# custom_properties {
#   key: "name"
#   value {
#     string_value: "rifkybujana-pipeline:20221109-114357.129105:Pusher:18:pushed_model:0"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.10.0"
#   }
# }
# name: "rifkybujana-pipeline:20221109-114357.129105:Pusher:18:pushed_model:0"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 18
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
